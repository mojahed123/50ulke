# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('50lke.csv')

# %%
df.head(5)
# Out:
#    SIRALAMA         ÜLKELER  MİLLİ GELİR     2023  BÜYÜME  KİŞİ BAŞINA  \
# 0         1   United States     20412.87  24537.0    2.27      62152.0
# 1         2           China     14092.51  21574.0    6.86      10088.0
# 2         3           Japan      5167.05   5962.0    1.71      40849.0
# 3         4         Germany      4211.64   5272.0    2.51      50842.0
# 4         5  United Kingdom      2936.29   3477.0    1.79      44177.0
#
#    SIRALAMA.2           KITA
# 0           9  North America
# 1          72           Asia
# 2          25           Asia
# 3          17         Europe
# 4          23         Europe

# %% [markdown]
# <b>Distribution Plot</b>

# %%
sns.distplot(df['BÜYÜME'],kde=True,color='red')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BÜYÜME', ylabel='Density'>

# %% [markdown]
# <b>Join Plot</b>

# %%
sns.jointplot(x='ÜLKELER',y='2023',data=df,kind='scatter')

# %% [markdown]
# <b>KDE Plot</b>

# %%
sns.kdeplot(df['SIRALAMA.2'],color='r')
# Out:
# <AxesSubplot:xlabel='SIRALAMA.2', ylabel='Density'>

# %% [markdown]
# <b>Pair Plot</b>

# %%
sns.pairplot(df)

# %% [markdown]
# <b>Rug Plot</b>

# %%
sns.rugplot(df['MİLLİ GELİR'])
# Out:
# <AxesSubplot:xlabel='MİLLİ GELİR'>

# %% [markdown]
# <b>Bar Plot</b>

# %%
sns.barplot(x='ÜLKELER',y='MİLLİ GELİR', data=df)
# Out:
# <AxesSubplot:xlabel='ÜLKELER', ylabel='MİLLİ GELİR'>

# %% [markdown]
# <b>Count Plot</b>

# %%
sns.countplot(x='KITA',data=df)
# Out:
# <AxesSubplot:xlabel='KITA', ylabel='count'>

# %% [markdown]
# <b>Box Plot</b>

# %%
sns.boxplot(x="KITA",y="BÜYÜME",data=df,palette="CMRmap_r")
# Out:
# <AxesSubplot:xlabel='KITA', ylabel='BÜYÜME'>
